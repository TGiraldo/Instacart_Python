# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/thaliagiraldo/Documents/Nov 2023 Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'),index_col = False)

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull()== True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull()== False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data','products_no_dups.csv'))

# %% [markdown]
# # Assignment Tasks 4.5

# %%
df_ords.describe()
#1 Basic Stats for the orders dataframe
# DOW COLUMN CHECK: MIN IS 0. MAX IS 2.3
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_last_order
# count        3.421083e+06       3.421083e+06           3.214874e+06
# mean         2.776219e+00       1.345202e+01           1.111484e+01
# std          2.046829e+00       4.226088e+00           9.206737e+00
# min          0.000000e+00       0.000000e+00           0.000000e+00
# ...

# %%
for col in df_ords.columns.tolist():
      weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_ords[weird]) > 0:
        print (col)
        
#3 Check for mixed data types 
#THERE ARE NO MIXED DATA TYPES

# %%
df_ords.drop(columns = ['Unnamed: 0'])
#Removed unnecessary column
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 1         2398795        1    prior             2                   3
# 2          473747        1    prior             3                   3
# 3         2254736        1    prior             4                   4
# 4          431534        1    prior             5                   4
# ...           ...      ...      ...           ...                 ...
# 3421078   2266710   206209    prior            10                   5
# 3421079   1854736   206209    prior            11                   4
# 3421080    626363   206209    prior            12                   1
# 3421081   2977660   206209    prior            13                   1
# 3421082    272231   206209    train            14                   6
#
#          order_hour_of_day  days_since_last_order
# 0                        8                    NaN
# ...

# %%
df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
df_ords.isnull().sum()
#5 Checking for missing values
#DAYS SINCE LAST ORDER HAS 206209 missing values
# Out:
# order_id                      0
# user_id                       0
# eval_set                      0
# order_number                  0
# orders_day_of_week            0
# order_hour_of_day             0
# days_since_last_order    206209
# dtype: int64

# %%
df_ords_nan = df_ords[df_ords['days_since_last_order'].isnull() == True]
# Created a new dataframe to see missing values

# %%
df_ords_nan
#Viewing missing values
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 11        2168274        2    prior             1                   2
# 26        1374495        3    prior             1                   1
# 39        3343014        4    prior             1                   6
# 45        2717275        5    prior             1                   3
# ...           ...      ...      ...           ...                 ...
# 3420930    969311   206205    prior             1                   4
# 3420934   3189322   206206    prior             1                   3
# 3421002   2166133   206207    prior             1                   6
# 3421019   2227043   206208    prior             1                   1
# 3421069   3154581   206209    prior             1                   3
#
#          order_hour_of_day  days_since_last_order
# 0                        8                    NaN
# ...

# %%
df_ords['order_number'].value_counts(dropna = False)
#viewing counts for how many customers this is their first order
# Out:
# order_number
# 1      206209
# 2      206209
# 3      206209
# 4      206209
# 5      182223
#         ...
# 96       1592
# 97       1525
# 98       1471
# 99       1421
# 100      1374
# Name: count, Length: 100, dtype: int64

# %%
# 6 - Addressing missing values
# I believe the 206209 missing values are linked with order numbers of 1 since it is the customers first order they would not have previous orders. In the missing values view you can see that all Order number 1 are missing and its exactly 206209 of them when looking at value_counts.

# %%
# Searching for duplicates
df_dups = df_ords[df_ords.duplicated()]

# %%
df_dups
#There are no duplicates
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_last_order]
# Index: []

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_cleaned.csv'))

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data','products_cleaned.csv'))
