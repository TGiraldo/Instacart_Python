# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Importing data sets
path = r'/Users/thaliagiraldo/Documents/Nov 2023 Instacart Basket Analysis'

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
#Checking shape of the data set from the assignment_ in pkl format
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
#Bringing in products dataset
products = pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_cleaned.csv'))

# %%
products
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
#Removing unnecessary column
products= products.drop(columns = ['Unnamed: 0'])

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# ...

# %%
# Merging data sets. Merged column already exists so creating a suffix column
merged_df = pd.merge(products, orders_products_combined, on=['product_id'], indicator='merge_indicator', suffixes=('_left', '_right'))

# %%
merged_df
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id eval_set  order_number  \
# ...

# %%
#Using merge flag to confirm the results of the merge
merged_df['merge_indicator'].value_counts()
# Out:
# merge_indicator
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
merged_df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_mergedcomplete.pkl'))
